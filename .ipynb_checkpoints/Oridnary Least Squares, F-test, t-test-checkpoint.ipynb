# %% [markdown]
# # Oridnary Least Squares, F-test, t-test

# %% [markdown]
# ## df_base

# %%
import pandas as pd

X_base_train = pd.read_pickle("X_base_train.pkl")
X_base_test = pd.read_pickle("X_base_test.pkl")
y_base_train = pd.read_pickle("y_base_train.pkl")
y_base_test = pd.read_pickle("y_base_test.pkl")

# %%
import statsmodels.api as sm

# Add constant (intercept)
X_train_sm = sm.add_constant(X_base_train)
y_train = y_base_train

# Fit OLS model
model = sm.OLS(y_train, X_train_sm).fit()

# Show summary with t-tests, p-values, R², etc.
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:       log_resale_price   R-squared:                       0.829
# Model:                            OLS   Adj. R-squared:                  0.828
# Method:                 Least Squares   F-statistic:                 2.304e+04
# Date:                Sat, 28 Jun 2025   Prob (F-statistic):               0.00
# Time:                        13:10:51   Log-Likelihood:             1.4949e+05
# No. Observations:              238444   AIC:                        -2.989e+05
# Df Residuals:                  238393   BIC:                        -2.984e+05
# Df Model:                          50
# Covariance Type:            nonrobust
# ...
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Analysis
# The F-test returns a p-value close to 0, indicating that the regression model as a whole is statistically significant — i.e., at least one predictor has a non-zero effect on resale price.
#
# The t-tests for individual coefficients identify six predictors that are not statistically significant at the 5% level (p > 0.05):
# town_SERANGOON, flat_model_Apartment, flat_model_Premium Apartment Loft, flat_model_Premium Maisonette, flat_model_Type S1, and flat_model_Type S2.
#
# Since the six predictors are one-hot encoded variables or dummy variables part of a category, we have decided to keep them instead of dropping.

# %% [markdown]
# ## df_post_covid

# %%
X_post_train = pd.read_pickle("X_post_train.pkl")
X_post_test = pd.read_pickle("X_post_test.pkl")
y_post_train = pd.read_pickle("y_post_train.pkl")
y_post_test = pd.read_pickle("y_post_test.pkl")

# %%
import statsmodels.api as sm

# Add constant (intercept)
X_train_sm = sm.add_constant(X_post_train)
y_train = y_post_train

# Fit OLS model
model = sm.OLS(y_train, X_train_sm).fit()

# Show summary with t-tests, p-values, R², etc.
print(model.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:       log_resale_price   R-squared:                       0.914
# Model:                            OLS   Adj. R-squared:                  0.914
# Method:                 Least Squares   F-statistic:                 2.378e+04
# Date:                Sat, 28 Jun 2025   Prob (F-statistic):               0.00
# Time:                        13:11:33   Log-Likelihood:             1.0641e+05
# No. Observations:              111545   AIC:                        -2.127e+05
# Df Residuals:                  111494   BIC:                        -2.122e+05
# Df Model:                          50
# Covariance Type:            nonrobust
# ...
#                                         coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------------------
# ...

# %% [markdown]
# ### Analysis
# The F-test returns a p-value close to 0, indicating that the regression model as a whole is statistically significant — i.e., at least one predictor has a non-zero effect on resale price.
#
# The t-tests for individual coefficients identify three predictors that are not statistically significant at the 5% level (p > 0.05):
# flat_model_Model A2, flat_model_New Generation, flat_model_Premium Apartment
#
# Since the three predictors are one-hot encoded variables or dummy variables part of a category, we have decided to keep them instead of dropping.
